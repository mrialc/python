# %%
import folium

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/manurial/Desktop/pontevedra.csv')

# %%
df.columns = df.columns.str.strip()

# %%
df.head()
# Out:
#      Código                         Nome  \
# 0  36000031      CEIP Antonio Carpintero
# 1  36000181             CEIP Amor Ruibal
# 2  36000247          CPI de Cova Terreña
# 3  36000302               CEP de Sabarís
# 4  36000326  CEIP Plurilingüe Montemogos
#
#                                Enderezo Concello   Provincia  Cód. postal  \
# 0  Rúa Miguel Davila, s/n (Consistorio)     Arbo  Pontevedra      36430.0
# 1              Perdecanai (Santa María)    Barro  Pontevedra      36194.0
# 2                    Dolores Agrelo s/n   Baiona  Pontevedra      36300.0
# 3  Avenida Doutor Fariñas, 26 (Sabarís)   Baiona  Pontevedra      36393.0
# 4                    Rúa Montemogos s/n     Bueu  Pontevedra      36937.0
#
#     Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# 0  886110092           CEIP     42.113000     -8.313560      Pública
# 1  886151996           CEIP     42.523860     -8.637228      Pública
# ...

# %%
df.tail()
# Out:
#        Código                                      Nome  \
# 601  36025037  CPR Plurilingüe Las Acacias-Montecastelo
# 602  36025049                              CPR San Eloy
# 603  36025050               CEMU Superior Galival Music
# 604  36025062                                CPR Premir
# 605  36025074                         EMUSPR de Agolada
#
#                                               Enderezo    Concello  \
# 601                            Rúa Doctor Paz Pardo 84        Vigo
# 602                                 Avenida da Ponte 9        Vigo
# 603  Lugar Auditorio Municipal (Lugar de Ferreirós)...       Valga
# 604                             Rúa Gagos de Mendoza 8  Pontevedra
# 605    Polígono Industrial de Merlín, Casa Amarela s/n     Agolada
#
#       Provincia  Cód. postal   Teléfono Tipo de centro  COORDENADA_X  \
# 601  Pontevedra      36214.0  986412488            CPR     42.212790
# 602  Pontevedra      36215.0        NaN            CPR     42.221817
# ...

# %%
subset_of_df=df.sample(n=605)

# %%
some_map=folium.Map(location=[subset_of_df['COORDENADA_X'].mean(),
                     subset_of_df['COORDENADA_Y'].mean()],
                     zoom_start=10)

# %%
for row in subset_of_df.itertuples():
    my_string = "PO-Centro",row.Código,row.COORDENADA_X,row.COORDENADA_Y
    some_map.add_child(folium.Marker(location=[row.COORDENADA_X,row.COORDENADA_Y],popup=(my_string)))

# %%
some_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import MarkerCluster

# %%
some_map_2=folium.Map(location=[subset_of_df['COORDENADA_X'].mean(),
                     subset_of_df['COORDENADA_Y'].mean()],
                     zoom_start=10)

# %%
mc=MarkerCluster()

# %%
for row in subset_of_df.itertuples():
    mc.add_child(folium.Marker(location=[row.COORDENADA_X,row.COORDENADA_Y],popup=row.Código))

# %%
some_map_2.add_child(mc)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
